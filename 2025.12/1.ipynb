# %%
# !pip install z3
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#      ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#      ---------------------------------------- 1.4/1.4 MB 6.2 MB/s eta 0:00:00
# ...
#   Created wheel for z3: filename=z3-0.2.0-py3-none-any.whl size=26642 sha256=01d6003ae8373113a196e65e9bccdda33bf14fe2756861de2002f90c8a22c170
#   Stored in directory: c:\users\jw\appdata\local\pip\cache\wheels\89\7a\2d\20eb825a16c87d6c22a1936e1af3839314d80293d705d1ff71
# Successfully built z3
# ...
#
#    ---------------------------------------- 0/2 [boto]
#    ---------------------------------------- 0/2 [boto]
#    ---------------------------------------- 0/2 [boto]
#    ---------------------------------------- 0/2 [boto]
#    ---------------------------------------- 0/2 [boto]
# ...
