# %%
# !pip install libcst mypy
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# Requirement already satisfied: libcst in d:\anaconda\lib\site-packages (1.8.6)
# Requirement already satisfied: mypy in d:\anaconda\lib\site-packages (1.14.1)
# Requirement already satisfied: pyyaml-ft>=8.0.0 in d:\anaconda\lib\site-packages (from libcst) (8.0.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in d:\anaconda\lib\site-packages (from mypy) (4.12.2)
# Requirement already satisfied: mypy-extensions>=1.0.0 in d:\anaconda\lib\site-packages (from mypy) (1.0.0)

# %%
# !pip install inspect
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ERROR: Could not find a version that satisfies the requirement inspect (from versions: none)
# ERROR: No matching distribution found for inspect

# %%
import  inspect

# %%
def foo():
    x=10
    return inspect.currentframe()
def bar():
    frame=foo()
    return frame

frame=bar()

# %%
frame.f_locals
# Out:
# {'x': 10}

# %%
frame.f_back.f_locals
# Out:
# {'frame': <frame at 0x000002159193D7A0, file 'C:\\Users\\Jw\\AppData\\Local\\Temp\\ipykernel_30900\\2037792635.py', line 3, code foo>}

# %%
frame.f_back.f_globals
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   "get_ipython().system('pip install libcst mypy')",
#   "get_ipython().system('pip install libcst mypy')",
#   "get_ipython().system('pip install libcst mypy')",
#   "get_ipython().system('pip install libcst mypy')",
#   "get_ipython().system('pip install inspect')",
#   "get_ipython().system('pip install inspect')",
#   "get_ipython().system('pip install inspect')",
#   "get_ipython().system('pip install inspect')",
#   'import  inspect',
#   'def foo():\n    x=10\n    return return inspect.currentframe()\ndef bar():\n    frame=foo()\n    return frame\n\nframe=bar()',
#   'def foo():\n    x=10\n    return inspect.currentframe()\ndef bar():\n    frame=foo()\n    return frame\n\nframe=bar()',
#   'frame.f_locals',
#   'frame.f_back.f_locals',
#   'frame.f_back.f_globals'],
#  '_oh': {12: {'x': 10},
#   13: {'frame': <frame at 0x000002159193D7A0, file 'C:\\Users\\Jw\\AppData\\Local\\Temp\\ipykernel_30900\\2037792635.py', line 3, code foo>}},
#  '_dh': [WindowsPath('D:/university/3rd/openSourceSoftware/2025.12')],
#  'In': ['',
#   "get_ipython().system('pip install libcst mypy')",
#   "get_ipython().system('pip install libcst mypy')",
#   "get_ipython().system('pip install libcst mypy')",
#   "get_ipython().system('pip install libcst mypy')",
#   "get_ipython().system('pip install inspect')",
#   "get_ipython().system('pip install inspect')",
#   "get_ipython().system('pip install inspect')",
#   "get_ipython().system('pip install inspect')",
#   'import  inspect',
#   'def foo():\n    x=10\n    return return inspect.currentframe()\ndef bar():\n    frame=foo()\n    return frame\n\nframe=bar()',
#   'def foo():\n    x=10\n    return inspect.currentframe()\ndef bar():\n    frame=foo()\n    return frame\n\nframe=bar()',
#   'frame.f_locals',
#   'frame.f_back.f_locals',
#   'frame.f_back.f_globals'],
#  'Out': {12: {'x': 10},
#   13: {'frame': <frame at 0x000002159193D7A0, file 'C:\\Users\\Jw\\AppData\\Local\\Temp\\ipykernel_30900\\2037792635.py', line 3, code foo>}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000002159156B380>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x2159160cc20>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x2159160cc20>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {'frame': <frame at 0x000002159193D7A0, file 'C:\\Users\\Jw\\AppData\\Local\\Temp\\ipykernel_30900\\2037792635.py', line 3, code foo>},
#  '__': {'x': 10},
#  '___': '',
#  '__session__': '2025.12/111.ipynb',
#  '_i': 'frame.f_back.f_locals',
#  '_ii': 'frame.f_locals',
#  '_iii': 'def foo():\n    x=10\n    return inspect.currentframe()\ndef bar():\n    frame=foo()\n    return frame\n\nframe=bar()',
#  '_i1': '!pip install libcst mypy',
#  '_exit_code': 1,
#  '_i2': '!pip install libcst mypy',
#  'sys': <module 'sys' (built-in)>,
#  'remove_imported_pydev_package': <function pydev_jupyter_utils.remove_imported_pydev_package()>,
#  '_pydevd_bundle': <module '_pydevd_bundle' from 'D:\\PyCharm 2025.1\\plugins\\python-ce\\helpers\\pydev\\_pydevd_bundle\\__init__.py'>,
#  'pydev_jupyter_vars': <module 'pydev_jupyter_vars' from 'D:\\PyCharm 2025.1\\plugins\\python-ce\\helpers\\jupyter_debug\\pydev_jupyter_vars.py'>,
#  '_i3': '!pip install libcst mypy',
#  '_i4': '!pip install libcst mypy',
#  '_i5': '!pip install inspect',
#  '_i6': '!pip install inspect',
#  '_i7': '!pip install inspect',
#  '_i8': '!pip install inspect',
#  '_i9': 'import  inspect',
#  'inspect': <module 'inspect' from 'C:\\Users\\Jw\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\inspect.py'>,
#  '_i10': 'def foo():\n    x=10\n    return return inspect.currentframe()\ndef bar():\n    frame=foo()\n    return frame\n\nframe=bar()',
#  '_i11': 'def foo():\n    x=10\n    return inspect.currentframe()\ndef bar():\n    frame=foo()\n    return frame\n\nframe=bar()',
#  'foo': <function __main__.foo()>,
#  'bar': <function __main__.bar()>,
#  'frame': <frame at 0x000002159193D7A0, file 'C:\\Users\\Jw\\AppData\\Local\\Temp\\ipykernel_30900\\2037792635.py', line 3, code foo>,
#  '_i12': 'frame.f_locals',
#  '_12': {'x': 10},
#  '_i13': 'frame.f_back.f_locals',
#  '_13': {'frame': <frame at 0x000002159193D7A0, file 'C:\\Users\\Jw\\AppData\\Local\\Temp\\ipykernel_30900\\2037792635.py', line 3, code foo>},
#  '_i14': 'frame.f_back.f_globals'}

# %%
x=10
def outer():
    x=20
    def inner():
        x=30
        return inspect.currentframe()
    return inner
fun=outer()
frame=fun()

# %%
frame.f_locals
# Out:
# {'x': 10}

# %% [markdown]
# sys monitoring
# 1.事件驱动模型
# 2.为每个不同的工具分配id
# 3.每个工具订阅自己关心的事件
